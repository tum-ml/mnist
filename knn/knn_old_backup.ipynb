# %%
import init
import mnistdata as mylib
import preprocessing as pp
    
gen = mylib.read("training","../data")
image = []
while (image != "None"):
    image = next(gen,"None")
    if image != "None":
        image = pp.thresholding(image[1],128)
        #image = pp.boundarysquare(image)
        image = pp.thin1(image,1)
        image = pp.thin1(image,2)
        image = pp.thin1(image,1)
        image = pp.thin1(image,2)
        mylib.show(image)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel/__main__.py:7: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-17e183483e42> in <module>()
#      14         image = pp.thin1(image,1)
#      15         image = pp.thin1(image,2)
# ---> 16         mylib.show(image)
#
# /home/sumit/Desktop/mnist/lib/mnistdata.py in show(image)
#      52     ax.xaxis.set_ticks_position('top')
#      53     ax.yaxis.set_ticks_position('left')
# ---> 54     pyplot.show()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in show(*args, **kw)
#     250     """
#     251     global _show
# --> 252     return _show(*args, **kw)
#     253
#     254
#
# /usr/local/lib/python3.5/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
# ...
